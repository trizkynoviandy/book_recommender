# %% [markdown]
# # Book Recommender System

# %%
import numpy as np
import pandas as pd

from sklearn.neighbors import NearestNeighbors

# %%
ratings = pd.read_csv("datasets/Ratings.csv", delimiter=";")
ratings.head()
# Out:
#    User-ID        ISBN  Rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5
# 2   276727  0446520802       0
# 3   276729  052165615X       3
# 4   276729  0521795028       6

# %%
books = pd.read_csv("datasets/Books.csv", delimiter=";")
books.head()
# Out:
#          ISBN                                              Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  Author  Year                Publisher
# 0    Mark P. O. Morford  2002  Oxford University Press
# 1  Richard Bruce Wright  2001    HarperFlamingo Canada
# 2          Carlo D'Este  1991          HarperPerennial
# 3      Gina Bari Kolata  1999     Farrar Straus Giroux
# 4       E. J. W. Barber  1999   W. W. Norton & Company

# %%
rating_books = pd.merge(ratings, books, on="ISBN")
rating_books.head()
# Out:
#    User-ID        ISBN  Rating                 Title      Author  Year  \
# 0   276725  034545104X       0  Flesh Tones: A Novel  M. J. Rose  2002
# 1     2313  034545104X       5  Flesh Tones: A Novel  M. J. Rose  2002
# 2     6543  034545104X       0  Flesh Tones: A Novel  M. J. Rose  2002
# 3     8680  034545104X       5  Flesh Tones: A Novel  M. J. Rose  2002
# 4    10314  034545104X       9  Flesh Tones: A Novel  M. J. Rose  2002
#
#           Publisher
# 0  Ballantine Books
# 1  Ballantine Books
# 2  Ballantine Books
# 3  Ballantine Books
# 4  Ballantine Books

# %%
rating_books_sample = rating_books.sample(frac=.01, random_state=1)

# %%
rating_books_pivot = rating_books_sample.pivot_table(index='Title', columns='User-ID', values='Rating').fillna(0)

# %%
rating_books_pivot.head()
# Out:
# User-ID                                             8       228     243     \
# Title
# 'A Hell of a Place to Lose a Cow': An American ...     0.0     0.0     0.0
# 01-01-00: The Novel of the Millennium                  0.0     0.0     0.0
# 1,001 Facts Somebody Screwed Up                        0.0     0.0     0.0
# 10 Steps in Writing the Research Paper (10 Step...     0.0     0.0     0.0
# 100 Great Archaeological Discoveries                   0.0     0.0     0.0
#
# User-ID                                             254     337     392     \
# Title
# 'A Hell of a Place to Lose a Cow': An American ...     0.0     0.0     0.0
# 01-01-00: The Novel of the Millennium                  0.0     0.0     0.0
# 1,001 Facts Somebody Screwed Up                        0.0     0.0     0.0
# 10 Steps in Writing the Research Paper (10 Step...     0.0     0.0     0.0
# 100 Great Archaeological Discoveries                   0.0     0.0     0.0
#
# User-ID                                             446     638     651     \
# Title
# 'A Hell of a Place to Lose a Cow': An American ...     0.0     0.0     0.0
# 01-01-00: The Novel of the Millennium                  0.0     0.0     0.0
# 1,001 Facts Somebody Screwed Up                        0.0     0.0     0.0
# 10 Steps in Writing the Research Paper (10 Step...     0.0     0.0     0.0
# 100 Great Archaeological Discoveries                   0.0     0.0     0.0
#
# User-ID                                             805     ...  278194  \
# Title                                                       ...
# 'A Hell of a Place to Lose a Cow': An American ...     0.0  ...     0.0
# 01-01-00: The Novel of the Millennium                  0.0  ...     0.0
# 1,001 Facts Somebody Screwed Up                        0.0  ...     0.0
# 10 Steps in Writing the Research Paper (10 Step...     0.0  ...     0.0
# 100 Great Archaeological Discoveries                   0.0  ...     0.0
#
# User-ID                                             278221  278376  278418  \
# Title
# 'A Hell of a Place to Lose a Cow': An American ...     0.0     0.0     0.0
# 01-01-00: The Novel of the Millennium                  0.0     0.0     0.0
# 1,001 Facts Somebody Screwed Up                        0.0     0.0     0.0
# 10 Steps in Writing the Research Paper (10 Step...     0.0     0.0     0.0
# 100 Great Archaeological Discoveries                   0.0     0.0     0.0
#
# User-ID                                             278535  278554  278582  \
# Title
# 'A Hell of a Place to Lose a Cow': An American ...     0.0     0.0     0.0
# 01-01-00: The Novel of the Millennium                  0.0     0.0     0.0
# 1,001 Facts Somebody Screwed Up                        0.0     0.0     0.0
# 10 Steps in Writing the Research Paper (10 Step...     0.0     0.0     0.0
# 100 Great Archaeological Discoveries                   0.0     0.0     0.0
#
# User-ID                                             278633  278668  278843
# Title
# 'A Hell of a Place to Lose a Cow': An American ...     0.0     0.0     0.0
# 01-01-00: The Novel of the Millennium                  0.0     0.0     0.0
# 1,001 Facts Somebody Screwed Up                        0.0     0.0     0.0
# 10 Steps in Writing the Research Paper (10 Step...     0.0     0.0     0.0
# 100 Great Archaeological Discoveries                   0.0     0.0     0.0
#
# [5 rows x 5263 columns]

# %%
knn = NearestNeighbors(metric='cosine', n_neighbors=5)
knn.fit(rating_books_pivot)
# Out:
# NearestNeighbors(metric='cosine')

# %%
book_title = ['100 Great Archaeological Discoveries']
indices=knn.kneighbors(rating_books_pivot.loc[book_title], 10, return_distance=False)

print("Recommended Books:\n")
for index, value in enumerate(np.array(rating_books_pivot.index)[indices][0]):
    print((index+1),". ",value)
# Out:
# Recommended Books:
#
# 1 .  Someday Angeline (Avon/Camelot Book)
# 2 .  Someday Soon
# 3 .  Some Can Whistle
# 4 .  Some Kind Of Incredible (20 Amber Court) (Silhoutte Desire, No. 1395)
# 5 .  Somebody Come and Play
# 6 .  Somebody'S Dead In Snellville
# 7 .  Someday (Denise Little Presents)
# 8 .  Solo
# 9 .  Something About Nothing
# 10 .  Something Wicked
